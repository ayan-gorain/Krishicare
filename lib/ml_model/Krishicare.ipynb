# %% [markdown]
# <a href="https://colab.research.google.com/github/ayan123gorain/Krishicare/blob/main/Krishicare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip drive/MyDrive/Krishicare/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2938.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2939.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy294.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2940.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2941.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2942.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2943.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2944.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2945.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2946.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2947.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2948.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2949.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy295.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2950.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2951.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2952.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2953.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2954.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2955.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2956.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2957.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2958.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2959.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy296.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2960.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2961.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2962.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2963.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2964.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2965.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2966.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2967.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2968.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2969.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy297.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2970.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2971.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2972.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2973.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2974.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2975.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2976.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2977.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2978.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2979.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy298.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2980.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2981.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2982.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2983.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2984.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2985.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2986.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2987.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2988.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2989.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy299.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2990.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2991.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2992.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2993.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2994.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2995.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2996.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2997.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2998.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy2999.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy30.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy300.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3000.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3001.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3002.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3003.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3004.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3005.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3006.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3007.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3008.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3009.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy301.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3010.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3011.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3012.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3013.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3014.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3015.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3016.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3017.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3018.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3019.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy302.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3020.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3021.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3022.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3023.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3024.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3025.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3026.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3027.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3028.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3029.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy303.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3030.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3031.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3032.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3033.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3034.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3035.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3036.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3037.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3038.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3039.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy304.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3040.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3041.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3042.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3043.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3044.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3045.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3046.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3047.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3048.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3049.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy305.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3050.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3051.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3052.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3053.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3054.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3055.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3056.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3057.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3058.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3059.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy306.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3060.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3061.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3062.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3063.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3064.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3065.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3066.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3067.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3068.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3069.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy307.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3070.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3071.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3072.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3073.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3074.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3075.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3076.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3077.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3078.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3079.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy308.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3080.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3081.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3082.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3083.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3084.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3085.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3086.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3087.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3088.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3089.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy309.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3090.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3091.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3092.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3093.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3094.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3095.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3096.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3097.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3098.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3099.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy31.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy310.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3100.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3101.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3102.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3103.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3104.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3105.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3106.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3107.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3108.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3109.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy311.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3110.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3111.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3112.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3113.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3114.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3115.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3116.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3117.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3118.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3119.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy312.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3120.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3121.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3122.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3123.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3124.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3125.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3126.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3127.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3128.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3129.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy313.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3130.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3131.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3132.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3133.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3134.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3135.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3136.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3137.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3138.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3139.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy314.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3140.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3141.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3142.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3143.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3144.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3145.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3146.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3147.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3148.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3149.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy315.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3150.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3151.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3152.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3153.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3154.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3155.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3156.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3157.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3158.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3159.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy316.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3160.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3161.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3162.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3163.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3164.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3165.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3166.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3167.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3168.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3169.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy317.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3170.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3171.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3172.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3173.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3174.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3175.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3176.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3177.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3178.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3179.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy318.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3180.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3181.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3182.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3183.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3184.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3185.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3186.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3187.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3188.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3189.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy319.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3190.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3191.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3192.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3193.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3194.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3195.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3196.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3197.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3198.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3199.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy32.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy320.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3200.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3201.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3202.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3203.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3204.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3205.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3206.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3207.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3208.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3209.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy321.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3210.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3211.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3212.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3213.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3214.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3215.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3216.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3217.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3218.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3219.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy322.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3220.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3221.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3222.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3223.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3224.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3225.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3226.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3227.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3228.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3229.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy323.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3230.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3231.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3232.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3233.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3234.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3235.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3236.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3237.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3238.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3239.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy324.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3240.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3241.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3242.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3243.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3244.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3245.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3246.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3247.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3248.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3249.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy325.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3250.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3251.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3252.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3253.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3254.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3255.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3256.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3257.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3258.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3259.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy326.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3260.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3261.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3262.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3263.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3264.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3265.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3266.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3267.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3268.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3269.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy327.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3270.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3271.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3272.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3273.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3274.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3275.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3276.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3277.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3278.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3279.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy328.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3280.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3281.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3282.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3283.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3284.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3285.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3286.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3287.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3288.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3289.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy329.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3290.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3291.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3292.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3293.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3294.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3295.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3296.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3297.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3298.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3299.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy33.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy330.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3300.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3301.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3302.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3303.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3304.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3305.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3306.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3307.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3308.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3309.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy331.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3310.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3311.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3312.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3313.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3314.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3315.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3316.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3317.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3318.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3319.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy332.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3320.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3321.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3322.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3323.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3324.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3325.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3326.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3327.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3328.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3329.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy333.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3330.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3331.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3332.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3333.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3334.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3335.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3336.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3337.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3338.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3339.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy334.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3340.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3341.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3342.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3343.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3344.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3345.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3346.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3347.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3348.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3349.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy335.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3350.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3351.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3352.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3353.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3354.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3355.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3356.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3357.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3358.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3359.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy336.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3360.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3361.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3362.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3363.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3364.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3365.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3366.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3367.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3368.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3369.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy337.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3370.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3371.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3372.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3373.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3374.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3375.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3376.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3377.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3378.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3379.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy338.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3380.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3381.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3382.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3383.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3384.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3385.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3386.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3387.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3388.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3389.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy339.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3390.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3391.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3392.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3393.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3394.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3395.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3396.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3397.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3398.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3399.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy34.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy340.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3400.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3401.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3402.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3403.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3404.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3405.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3406.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3407.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3408.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3409.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3410.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3411.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3412.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3413.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3414.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3415.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3416.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3417.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3418.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3419.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy342.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3420.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3421.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3422.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3423.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3424.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3425.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3426.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3427.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3428.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3429.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy343.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3430.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3431.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3432.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3433.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3434.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3435.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3436.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3437.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3438.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3439.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy344.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3440.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3441.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3442.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3443.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3444.jpg
#   inflating: Image Data base/Image Data base/Tomato healthy/Tomato_healthy3445.jpg
# ...
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea375.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea376.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea377.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea378.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea379.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea38.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea380.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea381.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea382.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea383.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea384.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea385.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea386.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea387.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea388.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea389.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea39.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea390.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea391.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea392.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea393.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea394.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea395.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea396.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea397.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea398.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea399.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea4.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea40.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea400.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea401.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea402.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea403.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea404.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea405.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea406.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea407.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea408.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea409.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea410.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea411.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea412.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea413.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea414.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea415.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea416.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea417.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea418.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea419.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea42.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea420.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea421.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea422.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea423.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea424.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea425.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea426.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea427.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea428.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea429.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea43.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea45.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea46.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea47.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea48.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea49.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea5.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea50.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea51.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea52.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea53.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea54.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea55.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea56.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea57.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea58.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea59.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea6.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea60.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea61.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea62.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea63.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea64.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea65.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea66.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea67.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea68.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea69.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea7.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea70.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea71.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea72.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea73.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea74.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea75.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea76.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea77.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea78.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea81.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea82.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea83.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea84.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea85.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea86.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea87.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea88.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea89.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea9.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea90.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea91.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea92.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea93.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea94.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea95.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea96.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea97.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea98.jpg
#   inflating: Image Data base/Image Data base/red leaf spot in tea/red_leaf_spot_in_tea99.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker1.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker10.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker11.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker12.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker13.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker14.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker15.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker16.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker17.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker18.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker19.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker2.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker20.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker21.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker22.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker23.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker24.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker25.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker26.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker27.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker28.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker29.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker3.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker30.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker31.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker32.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker33.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker34.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker35.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker36.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker37.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker38.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker39.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker4.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker40.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker41.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker42.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker43.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker44.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker45.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker46.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker47.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker48.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker49.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker5.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker50.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker51.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker52.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker53.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker54.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker55.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker56.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker57.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker6.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker7.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker8.jpg
#   inflating: Image Data base/Image Data base/tomato canker/tomato_canker9.jpg
#   inflating: plant diseases cure/cure.json

# %%
import numpy as np
import pandas as pd
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
import time

# %%
dir=r'/content/Image Data base/Image Data base'
min_samples=40 # set limit for minimum images a class must have to be included in the dataframe
filepaths = []
labels=[] 
classlist=os.listdir(dir)   
for klass in classlist:
    classpath=os.path.join(dir, klass)
    flist=os.listdir(classpath)
    if len(flist) >= min_samples:
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
    else:
        print('class ', klass, ' has only', len(flist), ' samples and will not be included in dataframe')
# Out:
# class  Waterlogging in plant  has only 21  samples and will not be included in dataframe
# class  Nitrogen deficiency in plant  has only 33  samples and will not be included in dataframe

# %%
Fseries=pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')        
df=pd.concat([Fseries, Lseries], axis=1)
train_df, dummy_df=train_test_split(df, train_size=.9, shuffle=True, random_state=123, stratify=df['labels'])
valid_df, test_df=train_test_split(dummy_df, train_size=.5, shuffle=True, random_state=123, stratify=dummy_df['labels'])
print('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df lenght:  179649   test_df length:  9981   valid_df length:  9981

# %%
classes=sorted(list(train_df['labels'].unique()))
class_count = len(classes)
print('The number of classes in the dataset is: ', class_count)
groups=train_df.groupby('labels')
print('{0:^30s} {1:^13s}'.format('CLASS', 'IMAGE COUNT'))
# Out:
# The number of classes in the dataset is:  56
#             CLASS               IMAGE COUNT

# %%
countlist=[]
classlist=[]
for label in sorted(list(train_df['labels'].unique())):
    group=groups.get_group(label)
    countlist.append(len(group))
    classlist.append(label)
    print('{0:^30s} {1:^13s}'.format(label, str(len(group))))
# Out:
#        Apple Apple scab            5443
#        Apple Black rot             5368
#     Apple Cedar apple rust         2376
#         Apple healthy              3553
# Bacterial leaf blight in rice leaf      108
#      Blight in corn Leaf           3094
#       Blueberry healthy            3245
#    Brown spot in rice leaf          108
#      Cercospora leaf spot           170
# Cherry (including sour) Powdery mildew     2273
# Cherry (including_sour) healthy     1847
#    Common Rust in corn Leaf        3526
#      Corn (maize) healthy          2511
#             Garlic                  132
#        Grape Black rot             10195
#    Grape Esca Black Measles        11956
# Grape Leaf blight Isariopsis Leaf Spot     9299
#         Grape healthy               915
#  Gray Leaf Spot in corn Leaf       1550
#     Leaf smut in rice leaf          108
# Orange Haunglongbing Citrus greening     47585
#         Peach healthy               778
#   Pepper bell Bacterial spot       2689
#      Pepper bell healthy           3194
#      Potato Early blight           2700
#       Potato Late blight           2700
#         Potato healthy              329
#       Raspberry healthy             802
#         Sogatella rice              70
#        Soybean healthy             10994
#     Strawberry Leaf scorch         2398
#       Strawberry healthy            985
#     Tomato Bacterial spot          5743
#      Tomato Early blight           2700
#       Tomato Late blight           5154
#        Tomato Leaf Mold            2570
#   Tomato Septoria leaf spot        4782
# Tomato Spider mites Two spotted spider mite     4525
#       Tomato Target Spot           3791
#   Tomato Tomato mosaic virus       1007
#         Tomato healthy             3437
#       algal leaf in tea             305
#       anthracnose in tea            270
#      bird eye spot in tea           270
#      brown blight in tea            305
#         cabbage looper              211
#           corn crop                 281
#             ginger                  122
#        healthy tea leaf             200
#          lemon canker               165
#             onion                   54
# potassium deficiency in plant       49
#          potato crop                108
#      potato hollow heart            162
#      red leaf spot in tea           386
#         tomato canker               51

# %%
max_value=np.max(countlist)
max_index=countlist.index(max_value)
max_class=classlist[max_index]
min_value=np.min(countlist)
min_index=countlist.index(min_value)
min_class=classlist[min_index]
print(max_class, ' has the most images= ',max_value, ' ', min_class, ' has the least images= ', min_value)

ht=0
wt=0

train_df_sample=train_df.sample(n=100, random_state=123,axis=0)
for i in range (len(train_df_sample)):
    fpath=train_df_sample['filepaths'].iloc[i]
    img=plt.imread(fpath)
    shape=img.shape
    ht += shape[0]
    wt += shape[1]
print('average height= ', ht//100, ' average width= ', wt//100, 'aspect ratio= ', ht/wt)
# Out:
# Orange Haunglongbing Citrus greening  has the most images=  47585   potassium deficiency in plant  has the least images=  49
# average height=  271  average width=  268 aspect ratio=  1.0095989284917033

# %%
diseases = os.listdir(dir)
print(diseases)
# Out:
# ['onion', 'algal leaf in tea', 'Tomato Tomato mosaic virus', 'Tomato Septoria leaf spot', 'Brown spot in rice leaf', 'healthy tea leaf', 'Grape Leaf blight Isariopsis Leaf Spot', 'Potato Early blight', 'Potato healthy', 'Cercospora leaf spot', 'tomato canker', 'bird eye spot in tea', 'Waterlogging in plant', 'Tomato Bacterial spot', 'Sogatella rice', 'Tomato healthy', 'Cherry (including sour) Powdery mildew', 'red leaf spot in tea', 'Corn (maize) healthy', 'Cherry (including_sour) healthy', 'Strawberry healthy', 'corn crop', 'Garlic', 'Apple healthy', 'lemon canker', 'Nitrogen deficiency in plant', 'Tomato Leaf Mold', 'Common Rust in corn Leaf', 'Blight in corn Leaf', 'brown blight in tea', 'Soybean healthy', 'Bacterial leaf blight in rice leaf', 'Gray Leaf Spot in corn Leaf', 'Apple Black rot', 'cabbage looper', 'Apple Apple scab', 'Grape Esca Black Measles', 'Tomato Spider mites Two spotted spider mite', 'Grape Black rot', 'anthracnose in tea', 'Strawberry Leaf scorch', 'ginger', 'Tomato Target Spot', 'potato hollow heart', 'Tomato Early blight', 'Leaf smut in rice leaf', 'Orange Haunglongbing Citrus greening', 'Blueberry healthy', 'Potato Late blight', 'Pepper bell Bacterial spot', 'Grape healthy', 'Tomato Late blight', 'Apple Cedar apple rust', 'Raspberry healthy', 'Peach healthy', 'Pepper bell healthy', 'potassium deficiency in plant', 'potato crop']

# %%
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# Total disease classes are: 58

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    return trimmed_df

# %%
max_samples=200 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=36
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  200  and the minimum samples in any class is  36

# %%
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')

image_path = '/content/Image Data base/Image Data base/Apple Black rot/Apple_Black_rot1002.jpg'
image = tf.io.read_file(image_path)
image = tf.io.decode_jpeg(image)

plt.figure(figsize=(6, 6))
plt.imshow(tf.squeeze(image), cmap='gray')
plt.axis('off')
plt.show();

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df['labels'].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class        
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False, 
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)            
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=os.listdir(classpath)    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df 

n=200 # number of samples in each class
working_dir=r'./' # directory to store augmented images
img_size=(200,200) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  10007
# Found 122 validated image filenames.
# Found 108 validated image filenames.
# Found 162 validated image filenames.
# Found 170 validated image filenames.
# Found 165 validated image filenames.
# Found 108 validated image filenames.
# Found 54 validated image filenames.
# Found 108 validated image filenames.
# Found 132 validated image filenames.
# Found 70 validated image filenames.
# Found 108 validated image filenames.
# Found 51 validated image filenames.
# Found 49 validated image filenames.
# Total Augmented images created=  1193
# Length of augmented dataframe is now  11200

# %%
batch_size=20 # We will use and EfficientetB3 model, with image size of (200, 250) this size should not cause resource error
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 11200 validated image filenames belonging to 56 classes.
# Found 9981 validated image filenames belonging to 56 classes.
# Found 9981 validated image filenames belonging to 56 classes.
# test batch size:  9   test steps:  1109  number of classes :  56

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image=images[i] /255       
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=14)
        plt.axis('off')
    plt.show()
    
show_image_samples(train_gen )

# %% [markdown]
# Create a model using transfer learning with EfficientNetB3

# %%
img_shape=(img_size[0], img_size[1], 3)
model_name='EfficientNetB3'
base_model=tf.keras.applications.efficientnet.EfficientNetB3(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 

base_model.trainable=True
x=base_model.output
x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=123)(x)       
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
lr=.001 # start with this learning rate
model.compile(Adamax(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 4s 0us/step

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        
        
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: 
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False 
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            print('Training will proceed until epoch', ask_epoch,' then you will be asked to') 
            print(' enter H to halt training or enter an integer for how many more epochs to run then be asked again')  
        self.start_time= time.time() # set the time at which training started
        
    def on_train_end(self, logs=None):   # runs at the end of training  
        print('loading model with weights from epoch ', self.best_epoch)
        self.model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print (msg, flush=True) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        if v_loss< self.lowest_vloss:
            self.lowest_vloss=v_loss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1
            print (f'\n validation loss of {v_loss:7.4f} is below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights')
        else:
            print (f'\n validation loss of {v_loss:7.4f} is above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights')
        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                print('\n Enter H to end training or  an integer for the number of additional epochs to run then ask again')
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    print ('you entered ', ans, ' Training halted on epoch ', epoch+1, ' due to user input\n', flush=True)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        print ('you entered ', ans, ' Training will continue to epoch ', self.ask_epoch, flush=True)
                        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                        print(f'current LR is  {lr:7.5f}  hit enter to keep  this LR or enter a new LR')
                        ans=input(' ')
                        if ans =='':
                            print (f'keeping current LR of {lr:7.5f}')
                        else:
                            new_lr=float(ans)
                            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                            print(' changing LR to ', ans)

# %%
epochs=40
ask_epoch=5
ask=LR_ASK(model, epochs,  ask_epoch)
#rlronp=tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2,verbose=1)
#callbacks=[rlronp, ask]
callbacks=[ask]

# %% [markdown]
# Training will proceed until epoch 5  then we will be asked to enter H to halt training or enter an integer for how many more epochs to run then be asked again

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 5  then you will be asked to
#  enter H to halt training or enter an integer for how many more epochs to run then be asked again
# Epoch 1/40
# 560/560 [==============================] - ETA: 0s - loss: 6.8386 - accuracy: 0.6499
#  validation loss of  3.7922 is below lowest loss, saving weights from epoch 1   as best weights
# 560/560 [==============================] - 345s 572ms/step - loss: 6.8386 - accuracy: 0.6499 - val_loss: 3.7922 - val_accuracy: 0.9278
# Epoch 2/40
# 560/560 [==============================] - ETA: 0s - loss: 2.7080 - accuracy: 0.9073
#  validation loss of  1.6112 is below lowest loss, saving weights from epoch 2   as best weights
# 560/560 [==============================] - 292s 521ms/step - loss: 2.7080 - accuracy: 0.9073 - val_loss: 1.6112 - val_accuracy: 0.9498
# Epoch 3/40
# 560/560 [==============================] - ETA: 0s - loss: 1.3269 - accuracy: 0.9401
#  validation loss of  0.8824 is below lowest loss, saving weights from epoch 3   as best weights
# 560/560 [==============================] - 294s 524ms/step - loss: 1.3269 - accuracy: 0.9401 - val_loss: 0.8824 - val_accuracy: 0.9705
# Epoch 4/40
# 560/560 [==============================] - ETA: 0s - loss: 0.8820 - accuracy: 0.9563
#  validation loss of  0.6375 is below lowest loss, saving weights from epoch 4   as best weights
# 560/560 [==============================] - 293s 523ms/step - loss: 0.8820 - accuracy: 0.9563 - val_loss: 0.6375 - val_accuracy: 0.9799
# Epoch 5/40
# 560/560 [==============================] - ETA: 0s - loss: 0.6958 - accuracy: 0.9681
#  validation loss of  0.5580 is below lowest loss, saving weights from epoch 5   as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# 1
# you entered  1  Training will continue to epoch  6
# current LR is  0.00100  hit enter to keep  this LR or enter a new LR
#
# keeping current LR of 0.00100
# 560/560 [==============================] - 319s 570ms/step - loss: 0.6958 - accuracy: 0.9681 - val_loss: 0.5580 - val_accuracy: 0.9789
# Epoch 6/40
# 560/560 [==============================] - ETA: 0s - loss: 0.6044 - accuracy: 0.9752
#  validation loss of  0.4834 is below lowest loss, saving weights from epoch 6   as best weights
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
# H
# you entered  H  Training halted on epoch  6  due to user input
#
# 560/560 [==============================] - 299s 533ms/step - loss: 0.6044 - accuracy: 0.9752 - val_loss: 0.4834 - val_accuracy: 0.9868
# loading model with weights from epoch  6
# training elapsed time was 0.0 hours, 30.0 minutes, 41.68 seconds)

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout    
    plt.show()
    
tr_plot(history,0)

# %%
def predictor(test_gen, test_steps):
    y_pred= []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100 
    print(f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}')
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests
errors, tests=predictor(test_gen, test_steps)
# Out:
# 1109/1109 [==============================] - 55s 46ms/step
# there were 141 errors in 9981 tests for an accuracy of  98.59
# Classification Report:
# ----------------------
#                                               precision    recall  f1-score   support
#
#                            Apple Apple scab     1.0000    0.9967    0.9983       303
#                             Apple Black rot     1.0000    0.9933    0.9966       298
#                      Apple Cedar apple rust     1.0000    1.0000    1.0000       132
#                               Apple healthy     0.9949    0.9899    0.9924       198
#          Bacterial leaf blight in rice leaf     1.0000    1.0000    1.0000         6
#                         Blight in corn Leaf     0.9157    0.8837    0.8994       172
#                           Blueberry healthy     0.9731    1.0000    0.9864       181
#                     Brown spot in rice leaf     1.0000    1.0000    1.0000         6
#                        Cercospora leaf spot     1.0000    1.0000    1.0000         9
#      Cherry (including sour) Powdery mildew     1.0000    0.9921    0.9960       126
#             Cherry (including_sour) healthy     0.9615    0.9804    0.9709       102
#                    Common Rust in corn Leaf     1.0000    0.9745    0.9871       196
#                        Corn (maize) healthy     0.9929    1.0000    0.9964       140
#                                      Garlic     0.8750    1.0000    0.9333         7
#                             Grape Black rot     0.9877    0.9965    0.9921       566
#                    Grape Esca Black Measles     0.9985    0.9895    0.9939       664
#      Grape Leaf blight Isariopsis Leaf Spot     0.9981    0.9961    0.9971       517
#                               Grape healthy     0.9444    1.0000    0.9714        51
#                 Gray Leaf Spot in corn Leaf     0.7812    0.8721    0.8242        86
#                      Leaf smut in rice leaf     1.0000    1.0000    1.0000         6
#        Orange Haunglongbing Citrus greening     1.0000    0.9992    0.9996      2643
#                               Peach healthy     0.9773    1.0000    0.9885        43
#                  Pepper bell Bacterial spot     0.9868    0.9933    0.9900       150
#                         Pepper bell healthy     0.9887    0.9831    0.9859       178
#                         Potato Early blight     0.9804    1.0000    0.9901       150
#                          Potato Late blight     0.9193    0.9867    0.9518       150
#                              Potato healthy     0.9500    1.0000    0.9744        19
#                           Raspberry healthy     1.0000    1.0000    1.0000        45
#                              Sogatella rice     1.0000    1.0000    1.0000         4
#                             Soybean healthy     0.9967    0.9918    0.9943       611
#                      Strawberry Leaf scorch     1.0000    0.9925    0.9962       133
#                          Strawberry healthy     0.9821    1.0000    0.9910        55
#                       Tomato Bacterial spot     0.9435    0.9937    0.9679       319
#                         Tomato Early blight     0.9692    0.8400    0.9000       150
#                          Tomato Late blight     0.9888    0.9199    0.9531       287
#                            Tomato Leaf Mold     0.9928    0.9650    0.9787       143
#                   Tomato Septoria leaf spot     0.9741    0.9925    0.9832       265
# Tomato Spider mites Two spotted spider mite     0.9918    0.9681    0.9798       251
#                          Tomato Target Spot     0.9623    0.9714    0.9668       210
#                  Tomato Tomato mosaic virus     0.9655    1.0000    0.9825        56
#                              Tomato healthy     0.9695    1.0000    0.9845       191
#                           algal leaf in tea     1.0000    1.0000    1.0000        17
#                          anthracnose in tea     1.0000    0.9333    0.9655        15
#                        bird eye spot in tea     0.8824    1.0000    0.9375        15
#                         brown blight in tea     1.0000    1.0000    1.0000        17
#                              cabbage looper     0.9167    1.0000    0.9565        11
#                                   corn crop     0.9412    1.0000    0.9697        16
#                                      ginger     1.0000    0.8333    0.9091         6
#                            healthy tea leaf     1.0000    1.0000    1.0000        11
#                                lemon canker     1.0000    1.0000    1.0000         9
#                                       onion     1.0000    1.0000    1.0000         3
#               potassium deficiency in plant     1.0000    1.0000    1.0000         3
#                                 potato crop     0.8571    1.0000    0.9231         6
#                         potato hollow heart     1.0000    1.0000    1.0000         9
#                        red leaf spot in tea     1.0000    1.0000    1.0000        21
#                               tomato canker     1.0000    1.0000    1.0000         3
#
#                                    accuracy                         0.9859      9981
#                                   macro avg     0.9743    0.9827    0.9778      9981
#                                weighted avg     0.9863    0.9859    0.9859      9981

# %%
subject='plant disease' 
acc=str(( 1-errors/tests) * 100)
index=acc.rfind('.')
acc=acc[:index + 3]
save_id= subject + '_' + str(acc) + '.h5' 
krishicare=os.path.join(working_dir, save_id)
model.save(krishicare)
print ('model was saved as ' , krishicare )
# Out:
# model was saved as  ./plant disease_98.58.h5
